# %% [markdown]
# <a href="https://colab.research.google.com/github/YaellOrtega/Actividad-4-Extracci-n-de-Caracter-sticas-/blob/main/Actividad_4_(Extracci%C3%B3n_de_Caracter%C3%ADsticas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Filtros por columnas
Micro_Retailer1=Micro_Retailer.iloc[ : , [3,9,10,11,12,18,19,23,24,25,30,32,34,47,48,53,54,55,66,67]]
Micro_Retailer1
# Out:
#               _updated_by                232_type_of_store  \
# 0    Salomon Abdala Perez                           Tailor
# 1    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 2    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 3    Salomon Abdala Perez   Grocery store (aka. nanostore)
# 4    Salomon Abdala Perez   Grocery store (aka. nanostore)
# ..                    ...                              ...
# 166          Emilio Garza   Grocery store (aka. nanostore)
# 167          Emilio Garza   Grocery store (aka. nanostore)
# 168          Emilio Garza  Micro-restaurant (aka. fondita)
# 169        Francisco Adán  Micro-restaurant (aka. fondita)
# 170          Emilio Garza  Micro-restaurant (aka. fondita)
#
#     108_does_the_micro_retailer_has_a_barred_window_  \
# 0                                                yes
# 1                                                 no
# 2                                                yes
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=Micro_Retailer1.isnull().sum()
valores_nulos
# Out:
# _updated_by                                                     0
# 232_type_of_store                                               0
# 108_does_the_micro_retailer_has_a_barred_window_                0
# 99_does_the_micro_retailer_exhibits_products_outside_           0
# 102_does_the_micro_retailer_sells_fresh_products_               0
# hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz      0
# le_comento_que_toda_esta_informacin_es_confidencial             0
# 5_change_store_space_last_year                                 72
# 6_change_employees_average_salary_last_year                    86
# 20_reviews_finances_monthly                                    63
# 19_tax_id                                                      71
# 310_burnout                                                    64
# 186_internet_connection                                        63
# 214_customer_relationship_tools                                76
# ...

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["5_change_store_space_last_year"] =Micro_Retailer1["5_change_store_space_last_year"].fillna(method="ffill")
# Out:
# <ipython-input-16-8c01eb225713>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Micro_Retailer1["5_change_store_space_last_year"] =Micro_Retailer1["5_change_store_space_last_year"].fillna(method="ffill")
# <ipython-input-16-8c01eb225713>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Micro_Retailer1["5_change_store_space_last_year"] =Micro_Retailer1["5_change_store_space_last_year"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=Micro_Retailer1.isnull().sum()
valores_nulos
# Out:
# _updated_by                                                     0
# 232_type_of_store                                               0
# 108_does_the_micro_retailer_has_a_barred_window_                0
# 99_does_the_micro_retailer_exhibits_products_outside_           0
# 102_does_the_micro_retailer_sells_fresh_products_               0
# hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz      0
# le_comento_que_toda_esta_informacin_es_confidencial             0
# 5_change_store_space_last_year                                  0
# 6_change_employees_average_salary_last_year                    86
# 20_reviews_finances_monthly                                    63
# 19_tax_id                                                      71
# 310_burnout                                                    64
# 186_internet_connection                                        63
# 214_customer_relationship_tools                                76
# ...

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["6_change_employees_average_salary_last_year"] =Micro_Retailer1["6_change_employees_average_salary_last_year"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["20_reviews_finances_monthly"] =Micro_Retailer1["20_reviews_finances_monthly"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["19_tax_id"] =Micro_Retailer1["19_tax_id"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["310_burnout"] =Micro_Retailer1["310_burnout"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["186_internet_connection"] =Micro_Retailer1["186_internet_connection"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["214_customer_relationship_tools"] =Micro_Retailer1["214_customer_relationship_tools"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["33_credit_to_customers"] =Micro_Retailer1["33_credit_to_customers"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["193_sales_planning_tools"] =Micro_Retailer1["193_sales_planning_tools"].fillna(method="ffill")

# %%
#Quinto método de sustitución de valores nulos
Micro_Retailer1["227_agreement_ecommerce_platforms"] =Micro_Retailer1["227_agreement_ecommerce_platforms"].fillna(method="ffill")

# %%
#Tercer método de sustitución de valores nulos
Micro_Retailer1["60_services"]= Micro_Retailer1["60_services"].fillna(10)
Micro_Retailer1

# %%
#Tercer método de sustitución de valores nulos
Micro_Retailer1["311_topups"]= Micro_Retailer1["311_topups"].fillna(10)
Micro_Retailer1

# %%
#Tercer método de sustitución de valores nulos
Micro_Retailer1["312_payment_of_utilities"]= Micro_Retailer1["312_payment_of_utilities"].fillna(10)
Micro_Retailer1

# %%
#Corroboramos valores nulos
valores_nulos=Micro_Retailer1.isnull().sum()
valores_nulos
# Out:
# _updated_by                                                   0
# 232_type_of_store                                             0
# 108_does_the_micro_retailer_has_a_barred_window_              0
# 99_does_the_micro_retailer_exhibits_products_outside_         0
# 102_does_the_micro_retailer_sells_fresh_products_             0
# hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz    0
# le_comento_que_toda_esta_informacin_es_confidencial           0
# 5_change_store_space_last_year                                0
# 6_change_employees_average_salary_last_year                   0
# 20_reviews_finances_monthly                                   0
# 19_tax_id                                                     0
# 310_burnout                                                   0
# 186_internet_connection                                       0
# 214_customer_relationship_tools                               0
# 33_credit_to_customers                                        0
# ...

# %%
#Verificamos información del DataFrame
Micro_Retailer1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 20 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   _updated_by                                                 171 non-null    object
#  1   232_type_of_store                                           171 non-null    object
#  2   108_does_the_micro_retailer_has_a_barred_window_            171 non-null    object
#  3   99_does_the_micro_retailer_exhibits_products_outside_       171 non-null    object
#  4   102_does_the_micro_retailer_sells_fresh_products_           171 non-null    object
#  5   hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz  171 non-null    object
#  6   le_comento_que_toda_esta_informacin_es_confidencial         171 non-null    object
# ...

# %%
#Imprimo los primeros 10 registro del dataframe
Micro_Retailer1.head(10)

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer1)

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['312_payment_of_utilities'])
table1
# Out:
#          312_payment_of_utilities  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         46    0.269006         0.696970
# 1           Totalmente de acuerdo          9    0.052632         0.833333
# 2                 Algo de acuerdo          5    0.029240         0.909091
# 3  Ni de acuerdo ni en desacuerdo          4    0.023392         0.969697
# 4              Algo en desacuerdo          2    0.011696         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#          312_payment_of_utilities  frequency  percentage  cumulative_perc
# 0        Totalmente en desacuerdo         46    0.269006         0.696970
# 1           Totalmente de acuerdo          9    0.052632         0.833333
# 2                 Algo de acuerdo          5    0.029240         0.909091
# 3  Ni de acuerdo ni en desacuerdo          4    0.023392         0.969697
# 4              Algo en desacuerdo          2    0.011696         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('312_payment_of_utilities')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 312_payment_of_utilities
# Totalmente en desacuerdo               46    0.269006         0.696970
# Totalmente de acuerdo                   9    0.052632         0.833333
# Algo de acuerdo                         5    0.029240         0.909091
# Ni de acuerdo ni en desacuerdo          4    0.023392         0.969697
# Algo en desacuerdo                      2    0.011696         1.000000

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('312_payment_of_utilities')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='311_topups'>

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>
